# %%
#all spark imports
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

#instantiate the spark session
spark = SparkSession.builder.appName("EDA_summary").getOrCreate()

#set the shuffle partition same as number of cpu cores to improve performance 
spark.conf.set("spark.sql.shuffle.partitions", 8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#read csv file with all data
all_DF = spark.read.csv("/FileStore/tables/GBatteries_alldata.csv", header = True, inferSchema = True)
                       
#cast time column as timestamp type from unix time
all_DF = all_DF.withColumn("time", all_DF["time"].cast(TimestampType())).cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#materialize the DF and display top 5 rows
display(all_DF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time</th><th>ocv</th><th>di</th><th>i0x2d</th><th>i0xc4</th><th>i0x91</th><th>i0x81</th><th>i0x40</th><th>i0x32</th><th>i0x65</th><th>i0x2</th><th>i0xbc</th><th>i0x30</th><th>i0x9f</th><th>i0x6b</th><th>i0x9</th><th>i0x8f</th><th>i0x3b</th><th>i0xc9</th><th>i0xb2</th><th>i0x14</th><th>i0x76</th><th>i0x29</th><th>i0x2c</th><th>i0xcd</th><th>i0x28</th><th>i0xb1</th><th>i0x83</th><th>i0x8c</th><th>i0x6</th><th>i0x5a</th><th>i0x78</th><th>i0xa7</th><th>i0x2a</th><th>i0x8a</th><th>i0xb6</th><th>i0x5</th><th>i0x94</th><th>i0x73</th><th>average_di</th><th>charge_duration</th><th>cell#</th><th>protocol</th><th>cycle</th></tr></thead><tbody><tr><td>2019-11-21T22:40:00.271+0000</td><td>2831.0</td><td>0.6350710900473934</td><td>0.0</td><td>0.0</td><td>0.2608695652173913</td><td>0.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.7382897149524921</td><td>0.09090909090909093</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.004502251125562781</td><td>0.7446808510638298</td><td>0.030947170990934667</td><td>0.652</td><td>0.4722222222222222</td><td>0.9473684210526316</td><td>0.0</td><td>1.0</td><td>0.0847457627118644</td><td>0.031719532554257086</td><td>0.020408163265306117</td><td>0.75</td><td>0.0</td><td>0.003001000333444481</td><td>0.003601440576230492</td><td>0.5627556737878638</td><td>599.9833333333332</td><td>5</td><td>fc8e420058ea073a58debc64048ea686c6aefdd3888d8d6005dd66d9ef5c2576</td><td>5</td></tr><tr><td>2019-11-21T22:40:10.544+0000</td><td>2883.0</td><td>0.6066350710900474</td><td>0.0</td><td>0.0</td><td>0.2608695652173913</td><td>0.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>0.7382897149524921</td><td>0.09090909090909093</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>1.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>1.0</td><td>0.0</td><td>0.004502251125562781</td><td>0.7446808510638298</td><td>0.030947170990934667</td><td>0.652</td><td>0.4722222222222222</td><td>0.9473684210526316</td><td>0.0</td><td>1.0</td><td>0.0847457627118644</td><td>0.031719532554257086</td><td>0.020408163265306117</td><td>0.75</td><td>0.0</td><td>0.003001000333444481</td><td>0.003601440576230492</td><td>0.5627556737878638</td><td>599.9833333333332</td><td>5</td><td>fc8e420058ea
072c8d23e1323372a1c33cb95de06fe3</td><td>74</td></tr><tr><td>f36836ee54508cbbc99e07d64683255a11bb1f3176c56bdd80bba3a09d68f8ab</td><td>19</td></tr><tr><td>f38daef78503f7c81cef066904fe29c4b2acf6acd96a0153230d80f21cd0905d</td><td>1020</td></tr><tr><td>f89b0ae3c67c80e30c07089eb90ab50ad0c817d39f05861fa9d9962ff45647d5</td><td>412</td></tr><tr><td>f94a27ee4db290ffb8d001b3c38117e1cdc43e6815b40d91cb62ff581abf6b48</td><td>58</td></tr><tr><td>fc8e420058ea073a58debc64048ea686c6aefdd3888d8d6005dd66d9ef5c2576</td><td>11</td></tr></tbody></table></div>

# %% [markdown]
# ## In total, how many cycles are recored in the data?

# %%
display(panel_DF.groupBy('protocol').agg(sum("count(cycle)").alias("protocol_total_cycles")).orderBy("protocol").select(sum("protocol_total_cycles").alias("total_cycles")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_cycles</th></tr></thead><tbody><tr><td>8354</td></tr></tbody></table></div>

# %%
#remove DF from memory
panel_DF.unpersist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: DataFrame[cell#: int, protocol: string, count(cycle): bigint]</div>

# %% [markdown]
# # Examination of features

# %% [markdown]
# ## what type of features do we have? How many unique values can they take?
# ### Binary features: 16;
# ### Ternary features: 6;
# ### Constant feature: 1;

# %%
distinct_cnt_DF = all_DF.agg(*(countDistinct(col(c)).alias(c) for c in all_DF.columns)).cache()
display(distinct_cnt_DF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time</th><th>ocv</th><th>di</th><th>i0x2d</th><th>i0xc4</th><th>i0x91</th><th>i0x81</th><th>i0x40</th><th>i0x32</th><th>i0x65</th><th>i0x2</th><th>i0xbc</th><th>i0x30</th><th>i0x9f</th><th>i0x6b</th><th>i0x9</th><th>i0x8f</th><th>i0x3b</th><th>i0xc9</th><th>i0xb2</th><th>i0x14</th><th>i0x76</th><th>i0x29</th><th>i0x2c</th><th>i0xcd</th><th>i0x28</th><th>i0xb1</th><th>i0x83</th><th>i0x8c</th><th>i0x6</th><th>i0x5a</th><th>i0x78</th><th>i0xa7</th><th>i0x2a</th><th>i0x8a</th><th>i0xb6</th><th>i0x5</th><th>i0x94</th><th>i0x73</th><th>average_di</th><th>charge_duration</th><th>cell#</th><th>protocol</th><th>cycle</th></tr></thead><tbody><tr><td>1275382</td><td>1214</td><td>211</td><td>2</td><td>3</td><td>18</td><td>2</td><td>2</td><td>3</td><td>2</td><td>259</td><td>3</td><td>2</td><td>2</td><td>2</td><td>2</td><td>1</td><td>2</td><td>2</td><td>2</td><td>2</td><td>2</td><td>2</td><td>2</td><td>70</td><td>12</td><td>16980</td><td>17</td><td>16</td><td>20</td><td>3</td><td>2</td><td>5</td><td>6</td><td>9</td><td>3</td><td>3</td><td>70</td><td>72</td><td>8043</td><td>394</td><td>20</td><td>28</td><td>1278</td></tr></tbody></table></div>

# %% [markdown]
# ### list all types of features

# %%
bin_ftr = [key for (key,value) in distinct_cnt_DF.collect()[0].asDict().items() if value == 2]
ter_ftr = [key for (key,value) in distinct_cnt_DF.collect()[0].asDict().items() if value == 3]
uni_ftr = [key for (key,value) in distinct_cnt_DF.collect()[0].asDict().items() if value == 1]
print('Binary features:', bin_ftr,'count:',len(bin_ftr), '\n')
print('Ternary features:', ter_ftr,'count:',len(ter_ftr), '\n')
print('Constant features:', uni_ftr,'count:',len(uni_ftr), '\n')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Binary features: [&#39;i0x2d&#39;, &#39;i0x81&#39;, &#39;i0x40&#39;, &#39;i0x65&#39;, &#39;i0x30&#39;, &#39;i0x9f&#39;, &#39;i0x6b&#39;, &#39;i0x9&#39;, &#39;i0x3b&#39;, &#39;i0xc9&#39;, &#39;i0xb2&#39;, &#39;i0x14&#39;, &#39;i0x76&#39;, &#39;i0x29&#39;, &#39;i0x2c&#39;, &#39;i0x78&#39;] count: 16
#
# Ternary features: [&#39;i0xc4&#39;, &#39;i0x32&#39;, &#39;i0xbc&#39;, &#39;i0x5a&#39;, &#39;i0xb6&#39;, &#39;i0x5&#39;] count: 6
#
# Constant features: [&#39;i0x8f&#39;] count: 1
#
# </div>

# %%
distinct_cnt_DF.unpersist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: DataFrame[time: bigint, ocv: bigint, di: bigint, i0x2d: bigint, i0xc4: bigint, i0x91: bigint, i0x81: bigint, i0x40: bigint, i0x32: bigint, i0x65: bigint, i0x2: bigint, i0xbc: bigint, i0x30: bigint, i0x9f: bigint, i0x6b: bigint, i0x9: bigint, i0x8f: bigint, i0x3b: bigint, i0xc9: bigint, i0xb2: bigint, i0x14: bigint, i0x76: bigint, i0x29: bigint, i0x2c: bigint, i0xcd: bigint, i0x28: bigint, i0xb1: bigint, i0x83: bigint, i0x8c: bigint, i0x6: bigint, i0x5a: bigint, i0x78: bigint, i0xa7: bigint, i0x2a: bigint, i0x8a: bigint, i0xb6: bigint, i0x5: bigint, i0x94: bigint, i0x73: bigint, average_di: bigint, charge_duration: bigint, cell#: bigint, protocol: bigint, cycle: bigint]</div>

# %% [markdown]
# ## What disctinct values each of the features have in the data?

# %%
#only interested in the unique values for charging parameters 
col_i0 = [c for c in all_DF.columns if c not in {'time','di','ocv','average_di', 'charge_duration',  'cycle', 'cell#', 'protocol'}]

all_DF.select([collect_set(c) for c in col_i0]).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>collect_set(i0x2d)</th>
#       <th>collect_set(i0xc4)</th>
#       <th>collect_set(i0x91)</th>
#       <th>collect_set(i0x81)</th>
#       <th>collect_set(i0x40)</th>
#       <th>collect_set(i0x32)</th>
#       <th>collect_set(i0x65)</th>
#       <th>collect_set(i0x2)</th>
#       <th>collect_set(i0xbc)</th>
#       <th>collect_set(i0x30)</th>
#       <th>collect_set(i0x9f)</th>
#       <th>collect_set(i0x6b)</th>
#       <th>collect_set(i0x9)</th>
#       <th>collect_set(i0x8f)</th>
#       <th>collect_set(i0x3b)</th>
#       <th>collect_set(i0xc9)</th>
#       <th>collect_set(i0xb2)</th>
#       <th>collect_set(i0x14)</th>
#       <th>collect_set(i0x76)</th>
#       <th>collect_set(i0x29)</th>
#       <th>collect_set(i0x2c)</th>
#       <th>collect_set(i0xcd)</th>
#       <th>collect_set(i0x28)</th>
#       <th>collect_set(i0xb1)</th>
#       <th>collect_set(i0x83)</th>
#       <th>collect_set(i0x8c)</th>
#       <th>collect_set(i0x6)</th>
#       <th>collect_set(i0x5a)</th>
#       <th>collect_set(i0x78)</th>
#       <th>collect_set(i0xa7)</th>
#       <th>collect_set(i0x2a)</th>
#       <th>collect_set(i0x8a)</th>
#       <th>collect_set(i0xb6)</th>
#       <th>collect_set(i0x5)</th>
#       <th>collect_set(i0x94)</th>
#       <th>collect_set(i0x73)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0, 0.42857142857142855]</td>
#       <td>[0.39130434782608703, 0.6086956521739131, 0.47...</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0, 0.5]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 0.5000833472245374, 0.5757626271045174, ...</td>
#       <td>[0.0, 0.09090909090909093, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 0.034517258629314665, 0.0006503251625812...</td>
#       <td>[0.0, 0.9574468085106383, 0.851063829787234, 1...</td>
#       <td>[0.0, 0.4480150046889653, 0.2406064395123476, ...</td>
#       <td>[0.0, 1.0, 0.44, 0.652, 0.632, 0.6920000000000...</td>
#       <td>[0.0, 1.0, 0.9305555555555556, 0.9402777777777...</td>
#       <td>[0.0, 0.917464114832536, 0.9138755980861244, 0...</td>
#       <td>[0.0, 0.75, 1.0]</td>
#       <td>[0.0, 1.0]</td>
#       <td>[0.0, 0.0847457627118644, 1.0, 0.8305084745762...</td>
#       <td>[0.0, 1.0, 0.0651085141903172, 0.0484140233722...</td>
#       <td>[0.0, 0.020408163265306117, 0.0244897959183673...</td>
#       <td>[0.0, 0.75, 1.0]</td>
#       <td>[0.0, 1.0, 0.5]</td>
#       <td>[0.0, 0.008002667555851951, 0.0225408469489829...</td>
#       <td>[0.0, 0.0156062424969988, 0.025610244097639057...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Which of the features remain constant for a protocol?
# ###features i0x30, i0x9f, and i0x2c remain constant for a cell-protocol combination

# %%
#count the number of distinct values of features for each cell-protocol combination
dst_cnt_cell_protocol_DF = all_DF.groupBy('cell#', 'protocol').agg(*[countDistinct(c) for c in col_i0]).orderBy("cell#", "protocol").cache()
display(dst_cnt_cell_protocol_DF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cell#</th><th>protocol</th><th>count(i0x2d)</th><th>count(i0xc4)</th><th>count(i0x91)</th><th>count(i0x81)</th><th>count(i0x40)</th><th>count(i0x32)</th><th>count(i0x65)</th><th>count(i0x2)</th><th>count(i0xbc)</th><th>count(i0x30)</th><th>count(i0x9f)</th><th>count(i0x6b)</th><th>count(i0x9)</th><th>count(i0x8f)</th><th>count(i0x3b)</th><th>count(i0xc9)</th><th>count(i0xb2)</th><th>count(i0x14)</th><th>count(i0x76)</th><th>count(i0x29)</th><th>count(i0x2c)</th><th>count(i0xcd)</th><th>count(i0x28)</th><th>count(i0xb1)</th><th>count(i0x83)</th><th>count(i0x8c)</th><th>count(i0x6)</th><th>count(i0x5a)</th><th>count(i0x78)</th><th>count(i0xa7)</th><th>count(i0x2a)</th><th>count(i0x8a)</th><th>count(i0xb6)</th><th>count(i0x5)</th><th>count(i0x94)</th><th>count(i0x73)</th></tr></thead><tbody><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>17</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>3</td><td>2</td><td>2</td><td>1</td><td>18</td><td>17</td></tr><tr><td>3</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>20</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>9</td><td>1</td><td>2</td><td>2</td><td>2</td><td>1</td><td>1</td><td>2</td><td>1</td><td>2</td><td>3</td><td>1</td><td>1</td><td>10</td><td>10</td></tr><tr><td>3</td><td>3c0dc4773fd8e5a688c248825e7a34367e8e5e8f8befd9b8211c6c387d22e116</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>2</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>2</td><td>2</td></tr><tr><td>3</td><td>84731643bd512e8095f1428a4275ed6e77b50eb9cc30cafd687112b37a25d711</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>21</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>14</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>2</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>15</td><td>14</td></tr><tr><td>3</td><td>8e01bf0c25fbfb5416f4a1bece6392e1cbf8b1e356b144389531e946c27f6437</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>3</td><td>e4615c5798e4279178bd1cfde95118076e87e25239e39b43291a6356b351bc37</td><td>2</td><td>1</td><td>5</td><td>1</td><td>2</td><td>1</td><td>2</td><td>27</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>7</td><td>3</td><td>4</td><td>5</td><td>1</td><td>2</td><td>1</td><td>2</td><td>2</td><td>2</td><td>1</td><td>2</td><td>2</td></tr><tr><td>4</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>18</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>8</td><td>1</td><td>1</td><td>2</td><td>2</td><td>2</td>< ...

# %%
#find which features have only one unique value for a cell_protocol combination
dst_cnt_cell_protocol_DF.select(*[collect_set(c) for c in dst_cnt_cell_protocol_DF.columns]).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>collect_set(cell#)</th>
#       <th>collect_set(protocol)</th>
#       <th>collect_set(count(i0x2d))</th>
#       <th>collect_set(count(i0xc4))</th>
#       <th>collect_set(count(i0x91))</th>
#       <th>collect_set(count(i0x81))</th>
#       <th>collect_set(count(i0x40))</th>
#       <th>collect_set(count(i0x32))</th>
#       <th>collect_set(count(i0x65))</th>
#       <th>collect_set(count(i0x2))</th>
#       <th>collect_set(count(i0xbc))</th>
#       <th>collect_set(count(i0x30))</th>
#       <th>collect_set(count(i0x9f))</th>
#       <th>collect_set(count(i0x6b))</th>
#       <th>collect_set(count(i0x9))</th>
#       <th>collect_set(count(i0x8f))</th>
#       <th>collect_set(count(i0x3b))</th>
#       <th>collect_set(count(i0xc9))</th>
#       <th>collect_set(count(i0xb2))</th>
#       <th>collect_set(count(i0x14))</th>
#       <th>collect_set(count(i0x76))</th>
#       <th>collect_set(count(i0x29))</th>
#       <th>collect_set(count(i0x2c))</th>
#       <th>collect_set(count(i0xcd))</th>
#       <th>collect_set(count(i0x28))</th>
#       <th>collect_set(count(i0xb1))</th>
#       <th>collect_set(count(i0x83))</th>
#       <th>collect_set(count(i0x8c))</th>
#       <th>collect_set(count(i0x6))</th>
#       <th>collect_set(count(i0x5a))</th>
#       <th>collect_set(count(i0x78))</th>
#       <th>collect_set(count(i0xa7))</th>
#       <th>collect_set(count(i0x2a))</th>
#       <th>collect_set(count(i0x8a))</th>
#       <th>collect_set(count(i0xb6))</th>
#       <th>collect_set(count(i0x5))</th>
#       <th>collect_set(count(i0x94))</th>
#       <th>collect_set(count(i0x73))</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[9, 1, 24, 3, 18, 10, 4, 11, 26, 27, 19, 13, 5...</td>
#       <td>[e85e6a6ab35f0bb2dea14e02ec68693d072c8d23e1323...</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 5, 2, 6, 3, 4]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2]</td>
#       <td>[27, 1, 20, 2, 50, 42, 21, 18, 22, 8, 23]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[15, 9, 1, 13, 2, 17, 50, 3, 10, 14, 11, 8]</td>
#       <td>[1, 2, 3]</td>
#       <td>[706, 2121, 1, 611, 1403, 10767, 205, 2, 286, ...</td>
#       <td>[1, 2, 3, 4]</td>
#       <td>[1, 5, 2, 3, 4]</td>
#       <td>[1, 5, 2, 3, 4]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[15, 1, 13, 2, 50, 3, 18, 10, 11, 8]</td>
#       <td>[15, 12, 1, 13, 2, 17, 50, 3, 10, 14, 8]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#remove DF from memory
dst_cnt_cell_protocol_DF.unpersist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: DataFrame[cell#: int, protocol: string, count(i0x2d): bigint, count(i0xc4): bigint, count(i0x91): bigint, count(i0x81): bigint, count(i0x40): bigint, count(i0x32): bigint, count(i0x65): bigint, count(i0x2): bigint, count(i0xbc): bigint, count(i0x30): bigint, count(i0x9f): bigint, count(i0x6b): bigint, count(i0x9): bigint, count(i0x8f): bigint, count(i0x3b): bigint, count(i0xc9): bigint, count(i0xb2): bigint, count(i0x14): bigint, count(i0x76): bigint, count(i0x29): bigint, count(i0x2c): bigint, count(i0xcd): bigint, count(i0x28): bigint, count(i0xb1): bigint, count(i0x83): bigint, count(i0x8c): bigint, count(i0x6): bigint, count(i0x5a): bigint, count(i0x78): bigint, count(i0xa7): bigint, count(i0x2a): bigint, count(i0x8a): bigint, count(i0xb6): bigint, count(i0x5): bigint, count(i0x94): bigint, count(i0x73): bigint]</div>

# %% [markdown]
# ## Which features remain constant for a protocol?
# ###features i0x9f and i0x2c remains constant for a given protocol

# %%
#count the number of distinct values of features for each protocol
dst_cnt_protocol_DF = all_DF.groupBy('protocol').agg(*[countDistinct(c) for c in col_i0]).orderBy('protocol').cache()
display(dst_cnt_protocol_DF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>protocol</th><th>count(i0x2d)</th><th>count(i0xc4)</th><th>count(i0x91)</th><th>count(i0x81)</th><th>count(i0x40)</th><th>count(i0x32)</th><th>count(i0x65)</th><th>count(i0x2)</th><th>count(i0xbc)</th><th>count(i0x30)</th><th>count(i0x9f)</th><th>count(i0x6b)</th><th>count(i0x9)</th><th>count(i0x8f)</th><th>count(i0x3b)</th><th>count(i0xc9)</th><th>count(i0xb2)</th><th>count(i0x14)</th><th>count(i0x76)</th><th>count(i0x29)</th><th>count(i0x2c)</th><th>count(i0xcd)</th><th>count(i0x28)</th><th>count(i0xb1)</th><th>count(i0x83)</th><th>count(i0x8c)</th><th>count(i0x6)</th><th>count(i0x5a)</th><th>count(i0x78)</th><th>count(i0xa7)</th><th>count(i0x2a)</th><th>count(i0x8a)</th><th>count(i0xb6)</th><th>count(i0x5)</th><th>count(i0x94)</th><th>count(i0x73)</th></tr></thead><tbody><tr><td>01fd02718c6b7aa23bdfb4c39aee1e7bd4355d4ff22bc01e752f2a1ba82d7b3c</td><td>2</td><td>2</td><td>2</td><td>1</td><td>1</td><td>3</td><td>2</td><td>2</td><td>2</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>2</td><td>2</td><td>2</td><td>1</td><td>1</td><td>2</td><td>1</td><td>3</td><td>2</td><td>2</td><td>3</td><td>3</td><td>4</td><td>1</td><td>2</td><td>2</td><td>2</td><td>2</td><td>2</td><td>1</td><td>3</td><td>3</td></tr><tr><td>0622d7ec92353d2cb635403db5f450c3f2b625ab2f2926661d687cf768ba8d4e</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>09942314d31dd2553f1e7f827d9e57ce8d811a8b9b7d8fe75fd372c4910b06db</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>0ee15df0e1233198be555cea609b7726e1dc914dfa3664a9ed67eca4dd6fb625</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>50</td><td>2</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>50</td><td>50</td></tr><tr><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>34</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>18</td><td>1</td><td>2</td><td>2</td><td>2</td><td>2</td><td>1</td><td>2</td><td>1</td><td>3</td><td>3</td><td>2</td><td>1</td><td>19</td><td>19</td></tr><tr><td>2683681f89ae95b058300629399b1bf3a89afa82e8a7588551b3fd1ce0155a99</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>286</td><td>2</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>3c0dc4773fd8e5a688c248825e7a34367e8e5e8f8befd9b8211c6c387d22e116</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>3</td><td>2</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>3</td><td>3</td><td>3</td><td>2</td><td>1</td><td>4</td><td>1</td><td>2</td><td>2</td><td>1</td><td>2</td><td>3</td><td>2</td><td>2</td><td>3</t ...

# %%
#find which features have only one unique value for a protocol
dst_cnt_protocol_DF.select(*[collect_set(c) for c in dst_cnt_protocol_DF.columns]).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>collect_set(protocol)</th>
#       <th>collect_set(count(i0x2d))</th>
#       <th>collect_set(count(i0xc4))</th>
#       <th>collect_set(count(i0x91))</th>
#       <th>collect_set(count(i0x81))</th>
#       <th>collect_set(count(i0x40))</th>
#       <th>collect_set(count(i0x32))</th>
#       <th>collect_set(count(i0x65))</th>
#       <th>collect_set(count(i0x2))</th>
#       <th>collect_set(count(i0xbc))</th>
#       <th>collect_set(count(i0x30))</th>
#       <th>collect_set(count(i0x9f))</th>
#       <th>collect_set(count(i0x6b))</th>
#       <th>collect_set(count(i0x9))</th>
#       <th>collect_set(count(i0x8f))</th>
#       <th>collect_set(count(i0x3b))</th>
#       <th>collect_set(count(i0xc9))</th>
#       <th>collect_set(count(i0xb2))</th>
#       <th>collect_set(count(i0x14))</th>
#       <th>collect_set(count(i0x76))</th>
#       <th>collect_set(count(i0x29))</th>
#       <th>collect_set(count(i0x2c))</th>
#       <th>collect_set(count(i0xcd))</th>
#       <th>collect_set(count(i0x28))</th>
#       <th>collect_set(count(i0xb1))</th>
#       <th>collect_set(count(i0x83))</th>
#       <th>collect_set(count(i0x8c))</th>
#       <th>collect_set(count(i0x6))</th>
#       <th>collect_set(count(i0x5a))</th>
#       <th>collect_set(count(i0x78))</th>
#       <th>collect_set(count(i0xa7))</th>
#       <th>collect_set(count(i0x2a))</th>
#       <th>collect_set(count(i0x8a))</th>
#       <th>collect_set(count(i0xb6))</th>
#       <th>collect_set(count(i0x5))</th>
#       <th>collect_set(count(i0x94))</th>
#       <th>collect_set(count(i0x73))</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[e85e6a6ab35f0bb2dea14e02ec68693d072c8d23e1323...</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 5, 2, 3, 8]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2]</td>
#       <td>[45, 1, 34, 37, 2, 28, 40, 8, 92]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[15, 1, 13, 2, 50, 3, 18, 10, 14]</td>
#       <td>[1, 2, 3]</td>
#       <td>[2121, 1, 2, 286, 1955, 10826, 3, 1977, 1523, ...</td>
#       <td>[1, 2, 3, 4]</td>
#       <td>[1, 2, 6, 3, 4]</td>
#       <td>[1, 5, 2, 3, 4]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2]</td>
#       <td>[15, 1, 19, 13, 2, 50, 3, 11]</td>
#       <td>[15, 1, 19, 2, 50, 3, 10, 14]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#remove DF from memeory
dst_cnt_protocol_DF.unpersist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: DataFrame[protocol: string, count(i0x2d): bigint, count(i0xc4): bigint, count(i0x91): bigint, count(i0x81): bigint, count(i0x40): bigint, count(i0x32): bigint, count(i0x65): bigint, count(i0x2): bigint, count(i0xbc): bigint, count(i0x30): bigint, count(i0x9f): bigint, count(i0x6b): bigint, count(i0x9): bigint, count(i0x8f): bigint, count(i0x3b): bigint, count(i0xc9): bigint, count(i0xb2): bigint, count(i0x14): bigint, count(i0x76): bigint, count(i0x29): bigint, count(i0x2c): bigint, count(i0xcd): bigint, count(i0x28): bigint, count(i0xb1): bigint, count(i0x83): bigint, count(i0x8c): bigint, count(i0x6): bigint, count(i0x5a): bigint, count(i0x78): bigint, count(i0xa7): bigint, count(i0x2a): bigint, count(i0x8a): bigint, count(i0xb6): bigint, count(i0x5): bigint, count(i0x94): bigint, count(i0x73): bigint]</div>

# %% [markdown]
# ## Which of the features remain constant during a cycle?

# %% [markdown]
# ### features constant in a cycle (total 19):
# ###['i0x2d', 'i0xc4', 'i0x81', 'i0x40', 'i0x32', 'i0xbc', 'i0x30', 'i0x9f', 'i0x6b', 'i0x9', 'i0x8f', 'i0x3b', 'i0xc9', 'i0xb2', 'i0x14', 'i0x76', 'i0x29', 'i0x2c', 'i0x5']
# ### (16 cycle specific, 3 from above which also remain constant for cell-protocol combination)

# %%
#count the number of distinct values of features for each cycle
dst_cnt_cycle_DF = all_DF.groupBy('cell#', 'protocol', 'cycle').agg(*[countDistinct(c).alias(c) for c in col_i0]).orderBy("cell#", "protocol", "cycle").cache()
display(dst_cnt_cycle_DF.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cell#</th><th>protocol</th><th>cycle</th><th>i0x2d</th><th>i0xc4</th><th>i0x91</th><th>i0x81</th><th>i0x40</th><th>i0x32</th><th>i0x65</th><th>i0x2</th><th>i0xbc</th><th>i0x30</th><th>i0x9f</th><th>i0x6b</th><th>i0x9</th><th>i0x8f</th><th>i0x3b</th><th>i0xc9</th><th>i0xb2</th><th>i0x14</th><th>i0x76</th><th>i0x29</th><th>i0x2c</th><th>i0xcd</th><th>i0x28</th><th>i0xb1</th><th>i0x83</th><th>i0x8c</th><th>i0x6</th><th>i0x5a</th><th>i0x78</th><th>i0xa7</th><th>i0x2a</th><th>i0x8a</th><th>i0xb6</th><th>i0x5</th><th>i0x94</th><th>i0x73</th></tr></thead><tbody><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>4</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>5</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>6</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>7</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>8</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>9</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</td><td>10</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>2</td><td>2</td><td>1</td><td>1</td><td>2</td><td>1</td></tr><tr><td>1</td><td>140f77741820c02177597651dfea9fe881c1a73d8e4002a87d0148967cc0f029</t ...

# %%
#find which features have only one unique value for a cycle
dst_cnt_cycle_DF.select(*[collect_set(c) for c in dst_cnt_cycle_DF.columns]).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>collect_set(cell#)</th>
#       <th>collect_set(protocol)</th>
#       <th>collect_set(cycle)</th>
#       <th>collect_set(i0x2d)</th>
#       <th>collect_set(i0xc4)</th>
#       <th>collect_set(i0x91)</th>
#       <th>collect_set(i0x81)</th>
#       <th>collect_set(i0x40)</th>
#       <th>collect_set(i0x32)</th>
#       <th>collect_set(i0x65)</th>
#       <th>collect_set(i0x2)</th>
#       <th>collect_set(i0xbc)</th>
#       <th>collect_set(i0x30)</th>
#       <th>collect_set(i0x9f)</th>
#       <th>collect_set(i0x6b)</th>
#       <th>collect_set(i0x9)</th>
#       <th>collect_set(i0x8f)</th>
#       <th>collect_set(i0x3b)</th>
#       <th>collect_set(i0xc9)</th>
#       <th>collect_set(i0xb2)</th>
#       <th>collect_set(i0x14)</th>
#       <th>collect_set(i0x76)</th>
#       <th>collect_set(i0x29)</th>
#       <th>collect_set(i0x2c)</th>
#       <th>collect_set(i0xcd)</th>
#       <th>collect_set(i0x28)</th>
#       <th>collect_set(i0xb1)</th>
#       <th>collect_set(i0x83)</th>
#       <th>collect_set(i0x8c)</th>
#       <th>collect_set(i0x6)</th>
#       <th>collect_set(i0x5a)</th>
#       <th>collect_set(i0x78)</th>
#       <th>collect_set(i0xa7)</th>
#       <th>collect_set(i0x2a)</th>
#       <th>collect_set(i0x8a)</th>
#       <th>collect_set(i0xb6)</th>
#       <th>collect_set(i0x5)</th>
#       <th>collect_set(i0x94)</th>
#       <th>collect_set(i0x73)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[9, 1, 24, 3, 18, 10, 4, 11, 26, 27, 19, 13, 5...</td>
#       <td>[e85e6a6ab35f0bb2dea14e02ec68693d072c8d23e1323...</td>
#       <td>[843, 356, 437, 793, 306, 387, 743, 256, 206, ...</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2, 3]</td>
#       <td>[102, 52, 2, 83, 156, 106, 98, 77, 48, 27, 121...</td>
#       <td>[1, 2, 3, 4]</td>
#       <td>[1, 2, 3, 4]</td>
#       <td>[1, 2, 3]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#       <td>[1]</td>
#       <td>[1, 2]</td>
#       <td>[1, 2]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#create a list of features that remain constant within a cycle
const_in_cycle = [key for (key,value) in dst_cnt_cycle_DF.select(*[collect_set(c).alias(c) for c in dst_cnt_cycle_DF.columns]).collect()[0].asDict().items() if value == [1]]

#list the names of features that are constant within a cycle
print('features constant in a cycle:', const_in_cycle)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">features constant in a cycle: [&#39;i0x2d&#39;, &#39;i0xc4&#39;, &#39;i0x81&#39;, &#39;i0x40&#39;, &#39;i0x32&#39;, &#39;i0xbc&#39;, &#39;i0x30&#39;, &#39;i0x9f&#39;, &#39;i0x6b&#39;, &#39;i0x9&#39;, &#39;i0x8f&#39;, &#39;i0x3b&#39;, &#39;i0xc9&#39;, &#39;i0xb2&#39;, &#39;i0x14&#39;, &#39;i0x76&#39;, &#39;i0x29&#39;, &#39;i0x2c&#39;, &#39;i0x5&#39;]
# </div>

# %%
#remove the DF from memory
dst_cnt_cycle_DF.unpersist()
all_DF.unpersist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: DataFrame[time: timestamp, ocv: double, di: double, i0x2d: double, i0xc4: double, i0x91: double, i0x81: double, i0x40: double, i0x32: double, i0x65: double, i0x2: double, i0xbc: double, i0x30: double, i0x9f: double, i0x6b: double, i0x9: double, i0x8f: double, i0x3b: double, i0xc9: double, i0xb2: double, i0x14: double, i0x76: double, i0x29: double, i0x2c: double, i0xcd: double, i0x28: double, i0xb1: double, i0x83: double, i0x8c: double, i0x6: double, i0x5a: double, i0x78: double, i0xa7: double, i0x2a: double, i0x8a: double, i0xb6: double, i0x5: double, i0x94: double, i0x73: double, average_di: double, charge_duration: double, cell#: int, protocol: string, cycle: int]</div>
